# %% [markdown]
# # NumericalMOOC Assignment Bank

# %% [markdown]
# ## Index of contributions

# %% [markdown]
# The IPython notebooks in this repository have been contributed by students and followers of the open course [**"Practical Numerical Methods with Python."**](http://openedx.seas.gwu.edu/courses/GW/MAE6286/2014_fall/about)
#
# Contributions are welcome, via pull request to the GitHub repository!
#
# 1. [1-D wave bar](./1D.Wave.Bar/1D.WaveBar.ipynb): solving the wave equation for a finite-length rod with a non-reflecting boundary condition on one end, by F. J. Gonzalez.
# 1. *"Shoot First, Ask Questions Later,"* or the [Blasius boundary-layer equation with shooting methods](./Blasius.Shooting.Method/01_shooting_blasius.ipynb), by Ian Carr [@iancarr](https://github.com/iancarr)
# 1. [Euler-Bernoulli beam equation](./Euler.Bernoulli.Beam.Equation/Euler.Bernoulli.Beam.Equation.ipynb), dramatically titled *"Lions, and Tigers, and 4th Order PDEs,"* by Matt Bornemeier [@bornemeierm](https://github.com/bornemeierm)
# 1. [Logistic equation with leapfrog method](./Logistic.Leap.Frog/LogisticLeapFrog.ipynb), a contribution by Sigurd Angenent [@SigurdAngenent](https://github.com/SigurdAngenent)
# 1. *"Learn to fly!"* [Navier-Stokes equation and immersed boundary method](./Navier.Stokes.Solver.Immersed.Boundary.Formulation/Navier_Stokes_Lesson.ipynb), by Akash Dhruv [@akidhruv](https://github.com/akidhruv)
# 1. [Lotka-Volterra equation for predator-prey models](./Predator.Prey.Model/Predator.Prey.Model.ipynb), by Sri Vallabha Deevi [@dsrivallabha](https://github.com/dsrivallabha)
# 1. [Particle-in-cell simulation for plasma modeling](./Particle.In.Cell.Simulations/PIC_Bonus_Notebook.ipynb), by Cameron Parvini [@cparvini](https://github.com/cparvini)
# 1. *"No Speeding Allowed,"* a lesson on [hyperbolic PDEs and the wave equation in 1D](./Wave.Equation/07_01_wave_equation_explicit.ipynb), with application to the vibrating-string problem, by Chase Johnson [@LTChaseJohnson](https://github.com/LTChaseJohnson). He also leaves you a challenge with the notebook posing the problem of [the wave equation with damping](.Wave.Equation/07_02_challenge_wave_equation_explicit.ipynb).

# %%
from IPython.core.display import HTML
css_file = '../styles/numericalmoocstyle.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(245,245,245);
# }
#
# div.cell { /* set cell width */
#     width: 750px;
# }
#
# div #notebook { /* centre the content */
# ...
